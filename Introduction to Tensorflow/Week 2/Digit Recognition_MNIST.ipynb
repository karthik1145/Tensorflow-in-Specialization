# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self,epochs,logs={}):
    if(logs.get('acc')>0.99):
      print("\nAccuracy Greater than 99%..")
      self.model.stop_training=True
stop=myCallback()
mnist=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train=x_train/255.0
x_test=x_test/255.0

model=tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                  tf.keras.layers.Dense(128,activation=tf.nn.relu),
                                  tf.keras.layers.Dense(10,activation=tf.nn.softmax)])
model.compile(optimizer=tf.train.AdamOptimizer(),loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=10,callbacks=[stop])

# %%
import matplotlib.pyplot as plt
plt.imshow(x_test[1001])

# %%
model.evaluate(x_test,y_test)
# Out:
# 10000/10000 [==============================] - 0s 36us/sample - loss: 0.0737 - acc: 0.9770
# [0.07371704301120481, 0.977]

# %%
classification=model.predict(x_test)
print(classification[1001])
print(y_test[1001])
# Out:
# [9.9983048e-01 6.5090169e-11 5.4916330e-07 1.3166030e-08 1.0842823e-10
#  2.5868081e-07 1.6773048e-04 3.8834256e-07 6.4080546e-11 4.4526624e-07]
# 0
