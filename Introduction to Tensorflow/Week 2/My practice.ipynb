# %%
import tensorflow as tf

# %%
mnist=tf.keras.datasets.fashion_mnist
(training_set,training_label),(test_set,test_label)=mnist.load_data()

# %%
import matplotlib.pyplot as plt
plt.imshow(training_set[0])
print(training_label[0])
print(training_set[0])

# %%
training_set=training_set/255.0
test_set=test_set/255.0

# %%
model=tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                  tf.keras.layers.Dense(128,activation=tf.nn.relu),
                                  tf.keras.layers.Dense(10,activation=tf.nn.softmax)])

# %%
model.compile(optimizer=tf.train.AdamOptimizer(),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(training_set,training_label,epochs=5)

# %%
model.evaluate(test_set,test_label)

# %%
classification=model.predict(test_set)

# %%
print(classification[5001])

# %%
print(test_label[5001])

# %% [markdown]
# **By adding more of neurons,accuracy improves but takes more time**

# %%
import tensorflow as tf
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self,epochs,logs={}):
    if(logs.get('loss')<0.4):
      self.model.stop_training=True

stop=myCallback()
mnist=tf.keras.datasets.fashion_mnist
(train_set,train_labels),(test_set,test_labels)=mnist.load_data()
train_set=train_set/255.0
test_set=test_set/255.0
model=tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                  tf.keras.layers.Dense(128,activation='relu'),
                                  #tf.keras.layers.Dense(256,activation='relu'),
                                  tf.keras.layers.Dense(10,activation='softmax')])
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy')
model.fit(train_set,train_labels,epochs=5,callbacks=[stop])
model.evaluate(test_set,test_labels)
classification=model.predict(test_set)
print(classification[0])
print(test_labels[0])
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 7s 121us/sample - loss: 0.4968
# Epoch 2/5
# ...
# 10000/10000 [==============================] - 1s 85us/sample - loss: 0.3901
# [8.04390311e-06 1.24561694e-07 7.51693335e-07 7.24096992e-07
#  2.63756601e-06 1.06564395e-01 1.70170442e-05 6.94272891e-02
#  3.56270146e-04 8.23622704e-01]
# 9
